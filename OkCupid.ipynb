# %%
#pets, smokes, religion

# %%
import pandas as pd

# %%
OkCupid=pd.read_csv('/Users/raphaelsirvent/Desktop/OKCUPID.csv')

# %%
OkCupid
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %% [markdown]
# # #Religion2

# %%
#only subsetting columns that have titles 
#removed the coulumns containing bios 
# should we assign dummy variables to certain columns for easier analysis? For example: sex, body_type, status, orientation
#should we create age cohorts?

OkCupid=OkCupid[['age', 'status', 'sex', 'orientation', 'body_type', 'diet', 'drinks',
       'drugs', 'education', 'ethnicity', 'height', 'income', 'job',
       'last_online', 'location', 'offspring', 'pets', 'religion', 'sign',
       'smokes', 'speaks']]

# %%
OkCupid["religion"].value_counts()
# Out:
# agnosticism                                   2724
# other                                         2691
# agnosticism but not too serious about it      2636
# agnosticism and laughing about it             2496
# catholicism but not too serious about it      2318
# atheism                                       2175
# other and laughing about it                   2119
# atheism and laughing about it                 2074
# christianity                                  1957
# christianity but not too serious about it     1952
# other but not too serious about it            1554
# judaism but not too serious about it          1517
# atheism but not too serious about it          1318
# catholicism                                   1064
# christianity and somewhat serious about it     927
# atheism and somewhat serious about it          848
# other and somewhat serious about it            846
# catholicism and laughing about it              726
# ...

# %%
#once we narrowed down the coulumns to be used for analysis, the next steps in tidying our data were: 
#1) fill-in missing values
#2) convert as many coulumns from strings to float for analysis (the first ones we converted were age, income, height)
#3)

# %%
OkCupid.insert(21, "religion2", Religion_2, True)

# %%
OkCupid["Religion2"].value_counts()
# Out:
# not serious about religion    21207
# other                          4070
# agnostic                       3680
# atheist                        3593
# christian                      3462
# catholic                       1714
# jewish                          900
# buddhist                        832
# hindu                           179
# islam                            83
# Name: Religion2, dtype: int64

# %%
Religion_2=[]
for x in range(len(OkCupid["religion"])):
    if (OkCupid.iloc[x]["religion"]== "agnosticism but not too serious about it") or (OkCupid.iloc[x]["religion"]== "catholicism but not too serious about it") or (OkCupid.iloc[x]["religion"]== "islam but not too serious about it")or (OkCupid.iloc[x]["religion"]== "hinduism but not too serious about it")or (OkCupid.iloc[x]["religion"]== "buddhism but not too serious about it") or (OkCupid.iloc[x]["religion"]== "judaism but not too serious about it")or (OkCupid.iloc[x]["religion"]== "atheism but not too serious about it")or (OkCupid.iloc[x]["religion"]== "other but not too serious about it")or (OkCupid.iloc[x]["religion"]== "christianity but not too serious about it"):
        Religion_2.append("not serious about religion")
    elif (OkCupid.iloc[x]["religion"]== "agnosticism and laughing about it") or (OkCupid.iloc[x]["religion"]== "catholicism and laughing about it") or (OkCupid.iloc[x]["religion"]== "islam and laughing about it")or (OkCupid.iloc[x]["religion"]== "hinduism and laughing about it")or (OkCupid.iloc[x]["religion"]== "buddhism and laughing about it") or (OkCupid.iloc[x]["religion"]== "judaism and laughing about it")or (OkCupid.iloc[x]["religion"]== "atheism and laughing about it")or (OkCupid.iloc[x]["religion"]== "other and laughing about it")or (OkCupid.iloc[x]["religion"]== "christianity and laughing about it"):
        Religion_2.append("not serious about religion")
    elif (OkCupid.iloc[x]["religion"]== "islam") or (OkCupid.iloc[x]["religion"]== "islam and very serious about it") or (OkCupid.iloc[x]["religion"]== "islam and somewhat serious about it"):
        Religion_2.append("islam")
    elif (OkCupid.iloc[x]["religion"]== "other") or (OkCupid.iloc[x]["religion"]== "other and very serious about it") or (OkCupid.iloc[x]["religion"]== "other and somewhat serious about it"):
        Religion_2.append("other")
    elif (OkCupid.iloc[x]["religion"]== "christianity") or (OkCupid.iloc[x]["religion"]== "christianity and very serious about it") or (OkCupid.iloc[x]["religion"]== "christianity and somewhat serious about it"):
        Religion_2.append("christian")
    elif (OkCupid.iloc[x]["religion"]== "catholicism") or (OkCupid.iloc[x]["religion"]== "catholicism and very serious about it") or (OkCupid.iloc[x]["religion"]== "catholicism and somewhat serious about it"):
        Religion_2.append("catholic")
    elif (OkCupid.iloc[x]["religion"]== "hinduism") or (OkCupid.iloc[x]["religion"]== "hinduism and very serious about it") or (OkCupid.iloc[x]["religion"]== "hinduism and somewhat serious about it"):
        Religion_2.append("hindu")
    elif (OkCupid.iloc[x]["religion"]== "judaism") or (OkCupid.iloc[x]["religion"]== "judaism and very serious about it") or (OkCupid.iloc[x]["religion"]== "judaism and somewhat serious about it"):
        Religion_2.append("jewish")
    elif (OkCupid.iloc[x]["religion"]== "atheism") or (OkCupid.iloc[x]["religion"]== "atheism and very serious about it") or (OkCupid.iloc[x]["religion"]== "atheism and somewhat serious about it"):
        Religion_2.append("atheist")
    elif (OkCupid.iloc[x]["religion"]== "buddhism") or (OkCupid.iloc[x]["religion"]== "buddhism and very serious about it") or (OkCupid.iloc[x]["religion"]== "buddhism and somewhat serious about it"):
        Religion_2.append("buddhist")
    elif (OkCupid.iloc[x]["religion"]== "agnosticism") or (OkCupid.iloc[x]["religion"]== "agnosticism and very serious about it") or (OkCupid.iloc[x]["religion"]== "agnosticism and somewhat serious about it"):
        Religion_2.append("agnostic")
    else:
        Religion_2.append(OkCupid.iloc[x]["religion"])

# %%
len(Religion_2)
# Out:
# 59946

# %% [markdown]
# # #Sina Relgion Method

# %%
OkCupid2=OkCupid

# %%
OkCupid2.shape
# Out:
# (59946, 24)

# %%
OkCupid2["religion"].value_counts()
# Out:
# agnosticism but not too serious about it      551
# catholicism but not too serious about it      463
# christianity but not too serious about it     447
# agnosticism and laughing about it             446
# atheism and laughing about it                 415
# other and laughing about it                   413
# other                                         397
# agnosticism                                   382
# other but not too serious about it            378
# atheism                                       265
# atheism but not too serious about it          259
# christianity                                  255
# judaism but not too serious about it          236
# christianity and somewhat serious about it    225
# other and somewhat serious about it           177
# atheism and somewhat serious about it         170
# catholicism and laughing about it             150
# atheism and very serious about it             128
# buddhism but not too serious about it         127
# ...

# %%
religion4=OkCupid2["religion"].tolist()

# %%
religion3=[1,2,3,1,2,3,6,7,8]

# %%
len(set(religion4))
# Out:
# 45

# %%
set(religion4)
# Out:
# {'agnosticism',
#  'agnosticism and laughing about it',
#  'agnosticism and somewhat serious about it',
#  'agnosticism and very serious about it',
#  'agnosticism but not too serious about it',
#  'atheism',
#  'atheism and laughing about it',
#  'atheism and somewhat serious about it',
#  'atheism and very serious about it',
#  'atheism but not too serious about it',
#  'buddhism',
#  'buddhism and laughing about it',
#  'buddhism and somewhat serious about it',
#  'buddhism and very serious about it',
#  'buddhism but not too serious about it',
#  'catholicism',
#  'catholicism and laughing about it',
#  'catholicism and somewhat serious about it',
#  'catholicism and very serious about it',
#  'catholicism but not too serious about it',
#  'christianity',
#  'christianity and laughing about it',
#  'christianity and somewhat serious about it',
#  'christianity and very serious about it',
#  'christianity but not too serious about it',
#  'hinduism',
# ...

# %%
keep_cats=["agnosticism",'atheism','buddhism','catholicism','christianity', 'hinduism', 'islam' ,'judaism', 'other',"NaN"]

# %%
keep_cats2=["laughing about it", "somewhat serious about it", "very serious about it"]

# %%
OkCupid2[OkCupid2["religion"].isin(keep_cats2)]
# Out:
# Empty DataFrame
# Columns: [age, status, sex, orientation, body_type, diet, drinks, drugs, education, ethnicity, height, income, job, last_online, location, offspring, pets, religion, sign, smokes, speaks, religion2, Religion2, pets2]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# # Raph new religion method

# %%
OkCupid4=OkCupid

# %%
OkCupid4["religion"].tolist()
# Out:
# ['agnosticism and very serious about it',
#  'agnosticism but not too serious about it',
#  nan,
#  nan,
#  nan,
#  'atheism',
#  nan,
#  'christianity',
#  'christianity but not too serious about it',
#  'atheism and laughing about it',
#  nan,
#  'christianity and very serious about it',
#  'other',
#  'christianity but not too serious about it',
#  'catholicism',
#  'atheism and laughing about it',
#  nan,
#  nan,
#  'christianity',
#  'catholicism but not too serious about it',
#  'catholicism',
#  'catholicism and somewhat serious about it',
#  'agnosticism and somewhat serious about it',
#  'atheism and laughing about it',
#  'other',
#  nan,
#  'catholicism and laughing about it',
#  'agnosticism and laughing about it',
#  'atheism and laughing about it',
#  'agnosticism and laughing about it',
#  'agnosticism',
#  'atheism',
#  'christianity',
#  nan,
#  'atheism and somewhat serious about it',
#  nan,
#  'buddhism but not too serious about it',
#  nan,
#  nan,
#  nan,
# ...

# %%
keep_cats=["agnosticism",'atheism','buddhism','catholicism','christianity', 'hinduism', 'islam' ,'judaism', 'other',"NaN", "not too serious about it", "laughing about it" ]

# %%
OkCupid4[OkCupid4["religion"].isin(keep_cats)]
# Out:
#        age  status sex orientation body_type               diet    drinks  \
# 5       29  single   m    straight   average    mostly anything  socially
# 7       31  single   f    straight   average    mostly anything  socially
# 12      24  single   m    straight       NaN                NaN     often
# 14      29  single   f    straight      thin    mostly anything  socially
# 18      31  single   m    straight   average  mostly vegetarian    rarely
# ...    ...     ...  ..         ...       ...                ...       ...
# 59933   30  single   f    straight       NaN                NaN  socially
# 59936   25  single   f    straight   average    mostly anything  socially
# 59938   48  single   m    straight   average                NaN       NaN
# 59940   31  single   f    straight       NaN                NaN  socially
# 59942   24  single   m    straight       fit    mostly anything     often
#
#            drugs                          education  \
# ...

# %%
MaxCheck3=librarySF[(librarySF["Outside of County"]==False)& (librarySF["Total Checkouts"])]

# %%
OkCupid
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %%
OkCupid["religion"].is_null().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-a4ec4dbe7fa5> in <module>
# ----> 1 OkCupid["religion"].is_null().sum()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'is_null'

# %% [markdown]
# # #pets

# %%
OkCupid["pets"].head(25)
# Out:
# 0        likes dogs and likes cats
# 1        likes dogs and likes cats
# 2                         has cats
# 3                       likes cats
# 4        likes dogs and likes cats
# 5                       likes cats
# 6        likes dogs and likes cats
# 7        likes dogs and likes cats
# 8        likes dogs and likes cats
# 9        likes dogs and likes cats
# 10                             NaN
# 11                      likes cats
# 12                             NaN
# 13         has dogs and likes cats
# 14         likes dogs and has cats
# 15         likes dogs and has cats
# 16       likes dogs and likes cats
# 17                             NaN
# 18       likes dogs and likes cats
# 19       likes dogs and likes cats
# 20    likes dogs and dislikes cats
# 21       likes dogs and likes cats
# 22       likes dogs and likes cats
# 23       likes dogs and likes cats
# 24                      likes cats
# Name: pets, dtype: object

# %%
pet_split=OkCupid["pets"].str.split("and")

# %%
pet_split.head(25)
# Out:
# 0        [likes dogs ,  likes cats]
# 1        [likes dogs ,  likes cats]
# 2                        [has cats]
# 3                      [likes cats]
# 4        [likes dogs ,  likes cats]
# 5                      [likes cats]
# 6        [likes dogs ,  likes cats]
# 7        [likes dogs ,  likes cats]
# 8        [likes dogs ,  likes cats]
# 9        [likes dogs ,  likes cats]
# 10                              NaN
# 11                     [likes cats]
# 12                              NaN
# 13         [has dogs ,  likes cats]
# 14         [likes dogs ,  has cats]
# 15         [likes dogs ,  has cats]
# 16       [likes dogs ,  likes cats]
# 17                              NaN
# 18       [likes dogs ,  likes cats]
# 19       [likes dogs ,  likes cats]
# 20    [likes dogs ,  dislikes cats]
# 21       [likes dogs ,  likes cats]
# 22       [likes dogs ,  likes cats]
# 23       [likes dogs ,  likes cats]
# 24                     [likes cats]
# Name: pets, dtype: object

# %%
pets2=[]
for x in range(len(OkCupid["pets"])):
    if (OkCupid.iloc[x]["pets"]== "has dogs and has cats") or (OkCupid.iloc[x]["pets"]== "likes dogs and likes cats") or (OkCupid.iloc[x]["pets"]== "likes dogs and has cats")or (OkCupid.iloc[x]["pets"]== "has dogs and likes cats"):
        pets2.append("likes dogs and cats")
    elif (OkCupid.iloc[x]["pets"]== "has dogs and dislikes cats") or (OkCupid.iloc[x]["pets"]== "has dogs") or (OkCupid.iloc[x]["pets"]== "has dogs and dislikes cats") or (OkCupid.iloc[x]["pets"]== "likes dogs"):
        pets2.append("likes dogs")
    elif (OkCupid.iloc[x]["pets"]== "has cats") or (OkCupid.iloc[x]["pets"]== "likes cats") or (OkCupid.iloc[x]["pets"]== "dislikes dogs and likes cats") or OkCupid.iloc[x]["pets"]== ("dislikes dogs and has cats"):
        pets2.append("likes cats")
    elif (OkCupid.iloc[x]["pets"]== "dislikes dogs and dislikes cats") or (OkCupid.iloc[x]["pets"]== "dislikes cats") or (OkCupid.iloc[x]["pets"]== "dislikes dogs"):
        pets2.append("dislikes dogs and cats")
    else:
        pets2.append(OkCupid.iloc[x]["pets"])

# %%
len(pets2)
# Out:
# 59946

# %%
OkCupid.insert(22,"pets2",pets2, True)

# %%
# what is our overall driving question?
#1 how does age, income, education, and height impact relationship status? #data modeling question
#2 what age cohort is likes to party the most? (party = drinks, drugs, and smokes)
#3 what are the main attributes of promiscuous daters?("seeing someone" but still looking) 
#4 how man general EDA questions should we choose? For example, women vs men, create age cohorts, etc

# %%
OkCupid["pets2"][smokes]
# Out:
# 0        likes dogs and cats
# 1        likes dogs and cats
# 2                 likes cats
# 3                 likes cats
# 4        likes dogs and cats
#                 ...
# 59941             likes dogs
# 59942    likes dogs and cats
# 59943                    NaN
# 59944    likes dogs and cats
# 59945    likes dogs and cats
# Name: pets2, Length: 59946, dtype: object

# %%
OkCupid5=OkCupid[["religion2","pets2","smokes"]]

# %%
OkCupid5.head(100)
# Out:
#                      religion2                pets2     smokes
# 0                     agnostic  likes dogs and cats  sometimes
# 1   not serious about religion  likes dogs and cats         no
# 2                          NaN           likes cats         no
# 3                          NaN           likes cats         no
# 4                          NaN  likes dogs and cats         no
# ..                         ...                  ...        ...
# 95  not serious about religion  likes dogs and cats         no
# 96                       other  likes dogs and cats         no
# 97                    agnostic                  NaN         no
# 98                     atheist           likes dogs         no
# 99                   christian                  NaN         no
#
# [100 rows x 3 columns]

# %%
print(OkCupid5["religion2"].value_counts())
# Out:
# not serious about religion    21207
# other                          4070
# agnostic                       3680
# atheist                        3593
# christian                      3462
# catholic                       1714
# jewish                          900
# buddhist                        832
# hindu                           179
# islam                            83
# Name: religion2, dtype: int64

# %%
print(OkCupid5["pets2"].value_counts())
# Out:
# likes dogs and cats             22934
# likes dogs                      11910
# likes cats                       2790
# likes dogs and dislikes cats     2029
# dislikes dogs and cats            362
# Name: pets2, dtype: int64

# %%
print(OkCupid5["smokes"].value_counts())
# Out:
# no                43896
# sometimes          3787
# when drinking      3040
# yes                2231
# trying to quit     1480
# Name: smokes, dtype: int64
